# %%
# !pip list
# Out:
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# Package                      Version
# ---------------------------- ----------------
# absl-py                      1.3.0
# astunparse                   1.6.3
# attrs                        21.2.0
# Automat                      20.2.0
# Babel                        2.8.0
# bcrypt                       3.2.0
# beniget                      0.4.1
# blinker                      1.4
# cachetools                   5.2.0
# certifi                      2025.7.14
# chardet                      4.0.0
# charset-normalizer           3.4.2
# click                        8.2.1
# cloud-init                   25.1.4
# cloudpickle                  3.1.1
# colorama                     0.4.4
# command-not-found            0.3
# configobj                    5.0.6
# constantly                   15.1.0
# contourpy                    1.0.6
# cryptography                 3.4.8
# cycler                       0.11.0
# dask                         2025.7.0
# dbus-python                  1.2.18
# decorator                    4.4.2
# distro                       1.7.0
# distro-info                  1.1+ubuntu0.2
# emoji                        2.14.1
# filelock                     3.18.0
# findspark                    2.0.1
# flatbuffers                  22.10.26
# fonttools                    4.38.0
# fsspec                       2025.7.0
# future                       0.18.2
# gast                         0.4.0
# google-auth                  2.14.1
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.50.0
# gyp                          0.1
# h5py                         3.7.0
# hf-xet                       1.1.5
# httplib2                     0.20.2
# huggingface-hub              0.34.3
# hyperlink                    21.0.0
# idna                         3.10
# imageio                      2.22.4
# importlib_metadata           8.7.0
# incremental                  21.3.0
# install                      1.3.5
# jeepney                      0.7.1
# Jinja2                       3.1.6
# joblib                       1.5.1
# jsonpatch                    1.32
# jsonpointer                  2.0
# jsonschema                   3.2.0
# jupyterlab_executor          2023.1.1
# keras                        2.10.0
# Keras-Preprocessing          1.1.2
# keyring                      23.5.0
# kiwisolver                   1.4.4
# launchpadlib                 1.10.16
# lazr.restfulclient           0.14.4
# lazr.uri                     1.0.6
# libclang                     14.0.6
# locket                       1.0.0
# Markdown                     3.4.1
# MarkupSafe                   3.0.2
# matplotlib                   3.6.2
# more-itertools               8.10.0
# mpmath                       1.3.0
# netifaces                    0.11.0
# networkx                     3.4.2
# nltk                         3.9.1
# numpy                        1.26.4
# nvidia-cublas-cu11           11.10.3.66
# nvidia-cublas-cu12           12.6.4.1
# nvidia-cuda-cupti-cu12       12.6.80
# nvidia-cuda-nvrtc-cu11       11.7.99
# nvidia-cuda-nvrtc-cu12       12.6.77
# nvidia-cuda-runtime-cu11     11.7.99
# nvidia-cuda-runtime-cu12     12.6.77
# nvidia-cudnn-cu11            8.5.0.96
# nvidia-cudnn-cu12            9.5.1.17
# nvidia-cufft-cu12            11.3.0.4
# nvidia-cufile-cu12           1.11.1.6
# nvidia-curand-cu12           10.3.7.77
# nvidia-cusolver-cu12         11.7.1.2
# nvidia-cusparse-cu12         12.5.4.2
# nvidia-cusparselt-cu12       0.6.3
# nvidia-nccl-cu12             2.26.2
# nvidia-nvjitlink-cu12        12.6.85
# nvidia-nvtx-cu12             12.6.77
# oauthlib                     3.2.0
# olefile                      0.46
# opt-einsum                   3.3.0
# packaging                    25.0
# pandas                       2.3.1
# partd                        1.4.2
# pexpect                      4.8.0
# Pillow                       9.0.1
# pip                          22.3.1
# ply                          3.11
# protobuf                     3.19.6
# psutil                       7.0.0
# ptyprocess                   0.7.0
# py4j                         0.10.9.7
# pyarrow                      21.0.0
# pyasn1                       0.4.8
# pyasn1-modules               0.2.1
# PyGObject                    3.42.1
# PyHamcrest                   2.0.2
# PyJWT                        2.3.0
# pyOpenSSL                    21.0.0
# pyparsing                    2.4.7
# pyrsistent                   0.18.1
# pyserial                     3.5
# pyspark                      3.4.0
# python-apt                   2.4.0+ubuntu4
# python-dateutil              2.9.0.post0
# python-debian                0.1.43+ubuntu1.1
# python-magic                 0.4.24
# pythran                      0.10.0
# pytz                         2025.2
# PyWavelets                   1.4.1
# PyYAML                       6.0.2
# regex                        2025.7.34
# rename                       22.12.0
# requests                     2.32.4
# requests-oauthlib            1.3.1
# rsa                          4.9
# safetensors                  0.5.3
# scikit-image                 0.19.3
# scikit-learn                 1.1.3
# scipy                        1.8.0
# screen-resolution-extra      0.0.0
# SecretStorage                3.3.1
# service-identity             18.1.0
# setuptools                   80.9.0
# Shapely                      1.8.5.post1
# six                          1.17.0
# sklearn                      0.0.post1
# sos                          4.5.6
# ssh-import-id                5.11
# swifter                      1.4.0
# sympy                        1.14.0
# systemd-python               234
# tensorboard                  2.10.1
# tensorboard-data-server      0.6.1
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.10.0
# tensorflow-estimator         2.10.0
# tensorflow-io-gcs-filesystem 0.27.0
# termcolor                    2.1.0
# threadpoolctl                3.1.0
# tifffile                     2022.10.10
# tokenizers                   0.21.4
# toolz                        1.0.0
# torch                        2.7.1
# torchaudio                   0.13.0
# torchvision                  0.8.0a0
# tqdm                         4.67.1
# transformers                 4.54.1
# triton                       3.3.1
# Twisted                      22.1.0
# typing_extensions            4.14.1
# tzdata                       2025.2
# ubuntu-advantage-tools       8001
# ubuntu-drivers-common        0.0.0
# ufw                          0.36.1
# unattended-upgrades          0.1
# urllib3                      2.5.0
# wadllib                      1.3.6
# Werkzeug                     2.2.2
# wheel                        0.37.1
# wrapt                        1.14.1
# xkit                         0.0.0
# zipp                         3.23.0
# zope.interface               5.4.0
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --force -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# Collecting pandas
#   Using cached pandas-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 8.3 MB/s eta 0:00:0000:01
# Collecting numpy<2.0,>=1.21
#   Using cached numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting emoji
#   Using cached emoji-2.14.1-py3-none-any.whl (590 kB)
# Collecting nltk
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting transformers
#   Using cached transformers-4.54.1-py3-none-any.whl (11.2 MB)
# Collecting torch>=2.6
#   Using cached torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting python-dateutil>=2.8.2
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting dill<0.3.9,>=0.3.0
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.7 MB/s eta 0:00:00
# Collecting filelock
#   Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.24.0
#   Using cached huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
# Collecting requests>=2.32.2
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting pyarrow>=15.0.0
#   Using cached pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.7 MB)
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.1 MB/s eta 0:00:00
# Collecting fsspec[http]<=2025.3.0,>=2023.1.0
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 10.0 MB/s eta 0:00:00
# Collecting packaging
#   Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Collecting regex>=2021.8.3
#   Using cached regex-2025.7.34-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (789 kB)
# Collecting joblib
#   Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Collecting click
#   Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Collecting safetensors>=0.4.3
#   Using cached safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Collecting tokenizers<0.22,>=0.21
#   Using cached tokenizers-0.21.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting nvidia-cusparse-cu12==12.5.4.2
#   Using cached nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
# Collecting nvidia-cufft-cu12==11.3.0.4
#   Using cached nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
# Collecting triton==3.3.1
#   Using cached triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
# Collecting nvidia-cufile-cu12==1.11.1.6
#   Using cached nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
# Collecting typing-extensions>=4.10.0
#   Using cached typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77
#   Using cached nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
# Collecting fsspec
#   Using cached fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
# Collecting nvidia-cusparselt-cu12==0.6.3
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
# Collecting nvidia-nvtx-cu12==12.6.77
#   Using cached nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77
#   Using cached nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1
#   Using cached nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
# Collecting nvidia-nccl-cu12==2.26.2
#   Using cached nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
# Collecting nvidia-nvjitlink-cu12==12.6.85
#   Using cached nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
# Collecting nvidia-cusolver-cu12==11.7.1.2
#   Using cached nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
# Collecting sympy>=1.13.3
#   Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80
#   Using cached nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Collecting networkx
#   Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Collecting nvidia-curand-cu12==10.3.7.77
#   Using cached nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
# Collecting setuptools>=40.8.0
#   Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.12.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.8 MB/s eta 0:00:00:00:01
# Collecting hf-xet<2.0.0,>=1.1.3
#   Using cached hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting six>=1.5
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2025.7.14-py3-none-any.whl (162 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.1/326.1 kB 16.9 MB/s eta 0:00:00
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 3.3 MB/s eta 0:00:00
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.3/198.3 kB 10.3 MB/s eta 0:00:00
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.6/241.6 kB 10.7 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.9/222.9 kB 10.9 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# Installing collected packages: pytz, nvidia-cusparselt-cu12, mpmath, xxhash, urllib3, tzdata, typing-extensions, tqdm, sympy, six, setuptools, safetensors, regex, pyyaml, pyarrow, propcache, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, joblib, idna, hf-xet, fsspec, frozenlist, filelock, emoji, dill, click, charset_normalizer, certifi, attrs, async-timeout, aiohappyeyeballs, triton, requests, python-dateutil, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nltk, multiprocess, multidict, jinja2, aiosignal, yarl, pandas, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, aiohttp, transformers, datasets
#   Attempting uninstall: pytz
#     WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: nvidia-cusparselt-cu12
#     WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
#     Found existing installation: nvidia-cusparselt-cu12 0.6.3
#     Uninstalling nvidia-cusparselt-cu12-0.6.3:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.3
# ERROR: Could not install packages due to an OSError: [Errno 16] Device or resource busy: '.nfs000000000000ece300000009'
#
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -vidia-cublas-cu12 (/home/tsaddi01/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
sys.path
# Out:
# ['/home/tsaddi01/msc-project-source-code-files-24-25-tayyib-saddique',
#  '/opt/conda/envs/pythontfv8/lib/python310.zip',
#  '/opt/conda/envs/pythontfv8/lib/python3.10',
#  '/opt/conda/envs/pythontfv8/lib/python3.10/lib-dynload',
#  '',
#  '/home/tsaddi01/.local/lib/python3.10/site-packages',
#  '/opt/conda/envs/pythontfv8/lib/python3.10/site-packages',
#  '/opt/conda/envs/pythontfv8/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg',
#  '/home/tsaddi01/.local/lib/python3.10/site-packages/setuptools/_vendor',
#  '/home/tsaddi01/.local/lib/python3.10/site-packages']

# %%
sys.path.append('/home/tsaddi01/.local/lib/python3.10/site-packages')

# %%
import transformers
